# %% [markdown]
# The goal of this script is to create a few charts and visualizations analyzing our tweets

# %%
import numpy as np
import pandas as pd
import os
import pickle
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
import gensim
from gensim import corpora
import pyLDAvis.gensim
from wordcloud import WordCloud
import textblob
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from datetime import datetime

# %%
DATA_DIR = "../../data/"

# %%
tweets = pd.read_csv(DATA_DIR + "tweet_scrape_2020_11_25.csv")

# %% [markdown]
# ### Preprocessing text

# %% [markdown]
# Use Porter stemmer + lemmatization: https://www.tutorialspoint.com/python_data_science/python_stemming_and_lemmatization.htm

# %% [markdown]
# Stemming:

# %%
porter_stemmer = PorterStemmer()

# %%
tweets["stemmed_text"] = [porter_stemmer.stem(text) for text in tweets["text"]]

# %% [markdown]
# Lemmatization

# %%
wordnet_lemmatizer = WordNetLemmatizer()

# %%
tweets["stemmed_lemmatized_text"] = [wordnet_lemmatizer.lemmatize(text) for text in tweets["stemmed_text"]]

# %%
tweets["stemmed_lemmatized_text"][0]
# Out:
# 'as a teacher i urge people to read this thread'

# %% [markdown]
# Remove links, @ mentions

# %%
def remove_links(tweet):
    '''Takes a string and removes web links from it'''
    tweet = re.sub(r'http\S+', '', tweet) # remove http links
    tweet = re.sub(r'bit.ly/\S+', '', tweet) # rempve bitly links
    tweet = tweet.strip('[link]') # remove [links]
    return tweet

# %%
def remove_users(tweet):
    '''Takes a string and removes retweet and @user information'''
    tweet = re.sub('(RT\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove retweet
    tweet = re.sub('(@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove tweeted at
    return tweet
# Out:
# <>:3: DeprecationWarning: invalid escape sequence \s
# <>:3: DeprecationWarning: invalid escape sequence \s
# <>:3: DeprecationWarning: invalid escape sequence \s
# <ipython-input-112-dc8996703f85>:3: DeprecationWarning: invalid escape sequence \s
#   tweet = re.sub('(RT\s@[A-Za-z]+[A-Za-z0-9-_]+)', '', tweet) # remove retweet

# %%
tweets["cleaned_text"] = [remove_links(tweet) for tweet in tweets["stemmed_lemmatized_text"]]
tweets["cleaned_text"] = [remove_users(tweet) for tweet in tweets["cleaned_text"]]

# %% [markdown]
# Remove punctuation

# %%
tweets["cleaned_text"] = [re.sub(r'[^\w\s]','', tweet) for tweet in tweets["cleaned_text"]]
tweets["cleaned_text"] = [re.sub(r'\n','', tweet) for tweet in tweets["cleaned_text"]]

# %% [markdown]
# Remove stopwords

# %%
eng_stopwords = stopwords.words('english')

# %%
tweets["cleaned_text"] = [" ".join([word.lower() for word in tweet.split(' ') if word not in eng_stopwords]) for tweet in tweets["cleaned_text"]]

# %% [markdown]
# Let's wrap all of this into one function:

# %%
def clean_text(tweet):
    
    """
    Runs all preprocessing steps above. 
    Input:
        • Takes one line of text / one tweet at a time
    Output:
        • Returns cleaned text
    """
    
    # stemming:
    porter_stemmer = PorterStemmer()
    tweet = porter_stemmer.stem(tweet)
    
    # lemmatization
    wordnet_lemmatizer = WordNetLemmatizer()
    tweet = wordnet_lemmatizer.lemmatize(tweet)
    
    # remove links, @ mentions (users)
    tweet = remove_links(tweet)
    tweet = remove_users(tweet)
    
    # remove punctuation, \n, \xa0
    tweet = re.sub(r'[^\w\s]','', tweet)
    tweet = re.sub(r'\n','', tweet)
    tweet = re.sub(r'\xa0', '', tweet)
    
    # remove stopwords
    eng_stopwords = stopwords.words('english')
    tweet = " ".join([word.lower() for word in tweet.split(' ') if word not in eng_stopwords])
    
    # get rid of extra spacing
    tweet = tweet.strip()
    
    # return cleaned tweet
    return tweet

# %% [markdown]
# ### Let's separate our tweets by depressed/anxious vs. not (using hard-coded dictionary of words), and see if we can do some preliminary analysis seeing if there's a difference in the tweets

# %%
depressed_count = 0

# %%
depression_words_list = ["depression", "dejected", "desperate", "sadness", "anxiety", 
                         "unhappy", "gloomy", "hopeless", "worry", "woeful", "upset", 
                         "sorry", "misery", "mental", "stress", "fear", "afraid"]

# %%
depression_words_list = [porter_stemmer.stem(text) for text in depression_words_list]

# %%
depression_words_list = [wordnet_lemmatizer.lemmatize(text) for text in depression_words_list]

# %%
depression_words_list
# Out:
# ['depress',
#  'deject',
#  'desper',
#  'sad',
#  'anxieti',
#  'unhappi',
#  'gloomi',
#  'hopeless',
#  'worri',
#  'woeful',
#  'upset',
#  'sorri',
#  'miseri',
#  'mental',
#  'stress',
#  'fear',
#  'afraid']

# %%
bool_arr_has_depressed_word = []

# %%
bool_word_depressed = False

# %%
for tweet in tweets["cleaned_text"]:
    for word in depression_words_list:
        if word in tweet:
            depressed_count = depressed_count + 1
            bool_arr_has_depressed_word.append(1)
            bool_word_depressed=True
            break
    if bool_word_depressed:
        bool_word_depressed=False
        continue
    bool_arr_has_depressed_word.append(0)

# %%
sum(bool_arr_has_depressed_word)
# Out:
# 294

# %%
tweets["is_depressed"] = bool_arr_has_depressed_word

# %%
# for depressed tweets
depressive_wc = WordCloud(width = 512,height = 512, collocations=False, colormap="Blues").generate(" ".join(list(tweets[tweets["is_depressed"]==1]["cleaned_text"])))
plt.figure(figsize = (10, 8), facecolor = 'k')
plt.imshow(depressive_wc)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()

# %%
# for non-depressed tweets
depressive_wc = WordCloud(width = 512,height = 512, collocations=False, colormap="viridis").generate(" ".join(list(tweets[tweets["is_depressed"]==0]["cleaned_text"])))
plt.figure(figsize = (10, 8), facecolor = 'k')
plt.imshow(depressive_wc)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()

# %% [markdown]
# #### When were the tweets posted?

# %%
tweets.head()
# Out:
#                   created_at  \
# 0  2020-11-25 11:33:12+00:00
# 1  2020-11-25 11:33:12+00:00
# 2  2020-11-25 11:33:12+00:00
# 3  2020-11-25 11:33:13+00:00
# 4  2020-11-25 11:33:13+00:00
#
#                                                 text             tweet_id  \
# 0     As a teacher I urge people to read this thread  1331561569545809920
# 1  @Yfm @LuckyStarSA #SouthAfricaRemix \nDuring t...  1331561569940025345
# 2  Nice walk after school run! \n#lockdown #annua...  1331561571798163457
# 3  Plans for the first weekend after lockdown: Ha...  1331561574268612609
# 4  @DanKennett @nnniner The first lockdown I agre...  1331561574209871872
#
#   user_screen_name                user_name              user_id  \
# 0       teacherken        Kenneth Bernstein             30686025
# 1    Tshego_Pretty  Tshegofatso _Mashiloane  1260439985246928898
# 2     AshPeelLowes      Ashleigh Peel-Lowes            755865500
# 3    ReinaaNatasha                     Tash            322261324
# ...

# %%
# e.g., 2020-11-25 11:33:12+00:00 --> 2020-11-25 11:33:12
tweets["tweet_time_str"] = [time.split('+')[0] for time in tweets["created_at"]]

# %%
# turn into datetime
tweets["tweet_time_datetime"] = [datetime.strptime(time, '%Y-%m-%d %H:%M:%S') for time in tweets["tweet_time_str"]]

# %%
# get hour of posting
tweets["hour_posted"] = [date.strftime("%m") for date in tweets["tweet_time_datetime"]]

# %%
tweets["hour_posted"].value_counts() 
# they were posted at the same time, because this is when I scraped them... but will do later...
# Out:
# 11    8178
# Name: hour_posted, dtype: int64

# %% [markdown]
# #### Is there a difference in the favorites or retweets or number of followers?

# %%
tweets.head()
# Out:
#                   created_at  \
# 0  2020-11-25 11:33:12+00:00
# 1  2020-11-25 11:33:12+00:00
# 2  2020-11-25 11:33:12+00:00
# 3  2020-11-25 11:33:13+00:00
# 4  2020-11-25 11:33:13+00:00
#
#                                                 text             tweet_id  \
# 0     As a teacher I urge people to read this thread  1331561569545809920
# 1  @Yfm @LuckyStarSA #SouthAfricaRemix \nDuring t...  1331561569940025345
# 2  Nice walk after school run! \n#lockdown #annua...  1331561571798163457
# 3  Plans for the first weekend after lockdown: Ha...  1331561574268612609
# 4  @DanKennett @nnniner The first lockdown I agre...  1331561574209871872
#
#   user_screen_name                user_name              user_id  \
# 0       teacherken        Kenneth Bernstein             30686025
# 1    Tshego_Pretty  Tshegofatso _Mashiloane  1260439985246928898
# 2     AshPeelLowes      Ashleigh Peel-Lowes            755865500
# 3    ReinaaNatasha                     Tash            322261324
# ...

# %%
# violinplot, how many followers a user has
sns.swarmplot(x = "is_depressed", y = "user_followers_count", data = tweets)
plt.show()

# %%
# violinplot, how many statuses a user has
sns.violinplot(x = "is_depressed", y = "user_statuses_count", data = tweets)
plt.show()

# %%
# looking at the number of favorites
sns.boxplot(tweets[["is_depressed", "user_followers_count"]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa085324fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fa085360400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa0853247f0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7fa0853608d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa085332320>,
# ...
#  'means': []}

# %% [markdown]
# ### Comparing COVID tweets to tweets about depression/mental health
#
# We now know that, at least in the dataset above, there aren't a lot of tweets on mental health topics. So, let's use a dataset that was intentionally scraped for mental health topics. The keywords for the old dataset were: [covid19, coronavirus, lockdown], and the keywords for the new dataset were: [depression, anxiety, fear, worry, distress, suicide, pain]

# %%
os.listdir(DATA_DIR)
# Out:
# ['tweet_scrape_2020-11-30_treatment.csv',
#  'twitter_scrape_tracker.csv',
#  'tweet_scrape_2020_11_25.json',
#  'tweet_scrape_2020-11-30_control.csv',
#  'tweet_scrape_2020-11-30_treatment.json',
#  'tweet_scrape_2020-11-30_control.json',
#  'tweet_scrape_2020_11_25.csv']

# %%
mental_tweets = pd.read_csv(DATA_DIR + "tweet_scrape_2020-11-30_treatment.csv")

# %%
mental_tweets.drop_duplicates(subset="tweet_id", inplace=True)
mental_tweets.reset_index(inplace=True)

# %%
mental_tweets.shape
# Out:
# (15777, 22)

# %%
mental_tweets["cleaned_text"] = [clean_text(tweet) for tweet in mental_tweets["text"]]

# %% [markdown]
# Let's get word clouds for both the COVID tweets and the mental health tweets, and see what the difference is:

# %% [markdown]
# For the COVID tweets:

# %%
# for non-depressed tweets
depressive_wc = WordCloud(width = 512,height = 512, collocations=False, colormap="viridis").generate(" ".join(list(tweets["cleaned_text"])))
plt.figure(figsize = (10, 8), facecolor = 'k')
plt.imshow(depressive_wc)
plt.axis('off')
plt.tight_layout(pad = 0)
#plt.savefig("wordcloud_covid_tweets_2020-11-30.png")
plt.show()

# %% [markdown]
# For the mental health tweets

# %%
# for depressed tweets
depressive_wc = WordCloud(width = 512,height = 512, collocations=False, colormap="Blues").generate(" ".join(list(mental_tweets["cleaned_text"])))
plt.figure(figsize = (10, 8), facecolor = 'k')
plt.imshow(depressive_wc)
plt.axis('off')
plt.tight_layout(pad = 0)
#plt.savefig("wordcloud_depression_tweets_2020-11-30.png")
plt.show()

# %% [markdown]
# Now, we know that our scrape of mental health tweets isn't perfect, since we did only a keyword match and not all the keywords will be used exclusively when someone is feeling depressed. Therefore, let's get a more fine-tuned evaluation of the sentiments in the mental health tweets

# %% [markdown]
# ### Let's create topic models for our tweets, using LDA
#
# Let's create separate topic models, one for our COVID tweets and one for our mental health tweets, and see if any patterns arise.
#
# I'll be following this walkthrough: https://datascienceplus.com/topic-modeling-in-python-with-nltk-and-gensim/

# %% [markdown]
# #### For the mental health tweets

# %%
mental_tweets["cleaned_text_tokenized"] = [tweet.split(' ') for tweet in mental_tweets["cleaned_text"]]

# %%
mental_tweets.head()
# Out:
#                   created_at  \
# 0  2020-11-30 21:10:05+00:00
# 1  2020-11-30 21:10:05+00:00
# 2  2020-11-30 21:10:05+00:00
# 3  2020-11-30 21:10:05+00:00
# 4  2020-11-30 21:10:05+00:00
#
#                                                 text     tweet_id  \
# 0  @AvelinoMorganti "...let me assert my firm bel...  1.33352e+18
# 1  @kodamq now we cant say ' speak to me when u r...  1.33352e+18
# 2  Miss Tolonda Tolbert's #HRTechConf keynote ses...  1.33352e+18
# 3  I go love you and I go leave you.. na the thin...  1.33352e+18
# 4  2 Timothy 1:7 “For God has not given us a spir...  1.33352e+18
#
#   user_screen_name           user_name       user_id  user_followers_count  \
# 0           bitdov            ₿it⚡️Dov  1.096870e+18                2284.0
# 1       sapphicelf      milf lover 100  1.285641e+18                  94.0
# 2       HRTechConf  HR Tech Conference  5.699505e+07               23359.0
# 3      EniolaHavoc            Meliodas  5.672534e+08                4101.0
# ...

# %%
# create dictionary, corpus for mental health tweets
dictionary_mental = corpora.Dictionary(mental_tweets["cleaned_text_tokenized"])
corpus_mental = [dictionary_mental.doc2bow(tweet) for tweet in mental_tweets["cleaned_text_tokenized"]]

# %%
# dump corpus as pickle
pickle.dump(corpus_mental, open('corpus_mental.pkl', 'wb'))
dictionary_mental.save('dictionary_mental.gensim')

# %%
# do LDA (try 10 topics)
NUM_TOPICS = 10
ldamodel_mental = gensim.models.ldamodel.LdaModel(corpus_mental, 
                                           num_topics = NUM_TOPICS, 
                                           id2word=dictionary_mental, 
                                           passes=15)
ldamodel_mental.save('model10_mental.gensim')
topics = ldamodel_mental.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.355*"" + 0.007*"depression" + 0.006*"1" + 0.006*"amp"')
# (1, '0.043*"worry" + 0.041*"dont" + 0.018*"im" + 0.013*"pain"')
# (2, '0.056*"pa" + 0.031*"fear" + 0.015*"people" + 0.008*"trump"')
# (3, '0.012*"amp" + 0.011*"like" + 0.010*"said" + 0.009*"wrong"')
# (4, '0.033*"depression" + 0.023*"suicide" + 0.014*"3" + 0.011*"amp"')
# (5, '0.034*"pain" + 0.018*"dey" + 0.013*"take" + 0.012*"lmao"')
# (6, '0.010*"yes" + 0.009*"amazing" + 0.008*"game" + 0.007*"running"')
# (7, '0.057*"anxiety" + 0.016*"fuck" + 0.010*"years" + 0.009*"social"')
# (8, '0.125*"pain" + 0.018*"feel" + 0.012*"im" + 0.011*"like"')
# (9, '0.126*"fear" + 0.014*"people" + 0.011*"need" + 0.010*"covid"')

# %%
# example (need to change var names):
#new_doc = 'Practical Bayesian Optimization of Machine Learning Algorithms'
#new_doc = prepare_text_for_lda(new_doc)
#new_doc_bow = dictionary.doc2bow(new_doc)
#print(new_doc_bow)
#print(ldamodel.get_document_topics(new_doc_bow))

# %%
#dictionary = gensim.corpora.Dictionary.load('dictionary.gensim')
#corpus = pickle.load(open('corpus.pkl', 'rb'))
#lda = gensim.models.ldamodel.LdaModel.load('model5.gensim')

lda_display = pyLDAvis.gensim.prepare(ldamodel_mental, 
                                      corpus_mental, 
                                      dictionary_mental, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el335351402734600634726509629276"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# Now, to do the same for the regular COVID tweets:

# %%
tweets["cleaned_text_tokenized"] = [tweet.split(' ') for tweet in tweets["cleaned_text"]]

# %%
tweets.head()
# Out:
#                   created_at  \
# 0  2020-11-25 11:33:12+00:00
# 1  2020-11-25 11:33:12+00:00
# 2  2020-11-25 11:33:12+00:00
# 3  2020-11-25 11:33:13+00:00
# 4  2020-11-25 11:33:13+00:00
#
#                                                 text             tweet_id  \
# 0     As a teacher I urge people to read this thread  1331561569545809920
# 1  @Yfm @LuckyStarSA #SouthAfricaRemix \nDuring t...  1331561569940025345
# 2  Nice walk after school run! \n#lockdown #annua...  1331561571798163457
# 3  Plans for the first weekend after lockdown: Ha...  1331561574268612609
# 4  @DanKennett @nnniner The first lockdown I agre...  1331561574209871872
#
#   user_screen_name                user_name              user_id  \
# 0       teacherken        Kenneth Bernstein             30686025
# 1    Tshego_Pretty  Tshegofatso _Mashiloane  1260439985246928898
# 2     AshPeelLowes      Ashleigh Peel-Lowes            755865500
# 3    ReinaaNatasha                     Tash            322261324
# ...

# %%
# create dictionary, corpus for mental health tweets
dictionary_covid = corpora.Dictionary(tweets["cleaned_text_tokenized"])
corpus_covid = [dictionary_covid.doc2bow(tweet) for tweet in tweets["cleaned_text_tokenized"]]

# %%
# dump corpus as pickle
pickle.dump(corpus_covid, open('corpus_covid_2020-11-30.pkl', 'wb'))
dictionary_covid.save('dictionary_covid_2020-11-30.gensim')

# %%
# do LDA (try 10 topics)
NUM_TOPICS = 10
ldamodel_covid = gensim.models.ldamodel.LdaModel(corpus_covid, 
                                           num_topics = NUM_TOPICS, 
                                           id2word=dictionary_covid, 
                                           passes=15)
ldamodel_covid.save('model10_covid_2020-11-30.gensim')
topics = ldamodel_covid.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.011*"worlds" + 0.008*"top" + 0.008*"sad" + 0.008*"perspective"')
# (1, '0.034*"lives" + 0.032*"families" + 0.027*"till" + 0.024*"risking"')
# (2, '0.204*"" + 0.030*"covid19" + 0.018*"coronavirus" + 0.017*"lockdown"')
# (3, '0.016*"lockdow" + 0.011*"shut" + 0.010*"fear" + 0.008*"touch"')
# (4, '0.078*"" + 0.030*"lockdown" + 0.011*"people" + 0.010*"coronavirus"')
# (5, '0.054*"" + 0.027*"lockdown" + 0.014*"people" + 0.011*"home"')
# (6, '0.021*"covid19" + 0.008*"lockdowns" + 0.008*"effective" + 0.007*"lockdown"')
# (7, '0.010*"symptoms" + 0.010*"flu" + 0.008*"conspiracy" + 0.007*"question"')
# (8, '0.072*"" + 0.053*"december" + 0.044*"sindh" + 0.030*"students"')
# (9, '0.026*"coronavirus" + 0.022*"postpone" + 0.018*"" + 0.016*"vaccine"')

# %%
lda_display_covid = pyLDAvis.gensim.prepare(ldamodel_covid, 
                                      corpus_covid, 
                                      dictionary_covid, sort_topics=False)
pyLDAvis.display(lda_display_covid)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el335351402735080310082838772023"></div>
# <script type="text/javascript">
#
# ...
